# %%
import numpy as np
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
with open('Уэллс_-_Война_миров.txt', 'r') as file:
    data = file.readlines()

# %%
data
# Out:
# '\n\nГерберт Уэллс\n\nВойна миров\n\n\nМоему брату Фрэнку Уэллсу, который подал мне мысль об этой книге.\n\nНо кто живет в этих мирах, если они обитаемы?.. Мы или они Владыки Мира? Разве все предназначено для человека?\nКеплер (Приведено у Бертона в «Анатомии меланхолии»)\n\n\nЧасть первая\n\n«Прибытие марсиан»\n\n\n\n\n1.\xa0Накануне войны\n\n\nНикто не поверил бы в последние годы девятнадцатого столетия, что за всем происходящим на Земле зорко и внимательно следят существа более развитые, чем человек, хотя такие же смертные, как и он; что в то время, как люди занимались своими делами, их исследовали и изучали, может быть, так же тщательно, как человек в микроскоп изучает эфемерных тварей, кишащих и размножающихся в капле воды. С бесконечным самодовольством сновали люди по всему земному шару, занятые своими делишками, уверенные в своей власти над материей. Возможно, что инфузория под микроскопом ведет себя так же. Никому не приходило в голову, что более старые миры вселенной – источ
# ...

# %%
tokenizer = RegexpTokenizer(r'\w+')
words = tokenizer.tokenize(''.join(data).lower())

# %%
words
# Out:
# ['герберт',
#  'уэллс',
#  'война',
#  'миров',
#  'моему',
#  'брату',
#  'фрэнку',
#  'уэллсу',
#  'который',
#  'подал',
#  'мне',
#  'мысль',
#  'об',
#  'этой',
#  'книге',
#  'но',
#  'кто',
#  'живет',
#  'в',
#  'этих',
#  'мирах',
#  'если',
#  'они',
#  'обитаемы',
#  'мы',
#  'или',
#  'они',
#  'владыки',
#  'мира',
#  'разве',
#  'все',
#  'предназначено',
#  'для',
#  'человека',
#  'кеплер',
#  'приведено',
#  'у',
#  'бертона',
#  'в',
#  'анатомии',
#  'меланхолии',
#  'часть',
#  'первая',
#  'прибытие',
#  'марсиан',
#  '1',
#  'накануне',
#  'войны',
#  'никто',
#  'не',
#  'поверил',
#  'бы',
#  'в',
#  'последние',
#  'годы',
#  'девятнадцатого',
#  'столетия',
#  'что',
#  'за',
#  'всем',
#  'происходящим',
#  'на',
#  'земле',
#  'зорко',
#  'и',
#  'внимательно',
#  'следят',
#  'существа',
#  'более',
#  'развитые',
#  'чем',
#  'человек',
#  'хотя',
#  'такие',
#  'же',
#  'смертные',
#  'как',
#  'и',
#  'он',
#  'что',
#  'в',
#  'то',
#  'время',
# ...

# %%
f'Количество строк в файле {len(data)}'
# Out:
# 'Количество строк в файле 2128'

# %%
f'Количество слов в файле {len(words)}'
# Out:
# 'Количество слов в файле 45078'

# %%
f'Количество символов(без пробелов) в файле {len("".join(words))}'
# Out:
# 'Количество символов(без пробелов) в файле 241149'

# %%
with open('Уэллс_-_Война_миров.txt', 'r') as file:
    data = file.read()

# %%
f'Количество символов(c пробелами) в файле {len(data)}'
# Out:
# 'Количество символов(c пробелами) в файле 298375'

# %%
from collections import Counter
word_freq = Counter(words)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(background_color='white')
wordcloud.generate_from_frequencies(word_freq)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#почистим от стопслов(местоимения и тд)

# %%
from nltk.corpus import stopwords
stopwords = set(stopwords.words('russian'))
words = [i for i in words if i not in stopwords]
word_freq = Counter(words)

# %%
wordcloud = WordCloud(background_color='white')
wordcloud.generate_from_frequencies(word_freq)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
